# %% [markdown]
# # Agentic Coffee Shop - **Exercise 3: Extensions**
#
# <div style="font-size: x-large; text-align: center;">Welcome in our Agentic Coffee Shop</div>
#
# <div style="font-size: x-large; text-align: center;">
# <br/>
# <img src="assets/Exercise 3.png" alt="Agentic Coffee Shop" width="500"/>
# </div>
#
# <p style="font-size: x-large; text-align: center;">
# The basics are brewing, now it’s time to innovate. <br/>
# This is your chance to evolve the experience — <br/>one smart sip at a time.
# </p>
#
# In this third exercise, you have the chance to further play around with the Coffee Shop agents, adapt the Coffee Shop to your own ideas, and analyze the changed behavior. This notebook is similar to the previous ones and can be seen as a sandbox to your own experiments. We will only ask for one adaptation, give some ideas for further changes and leave the rest to you.
#
# So, let's start and have fun ...

# %% [markdown]
# ## 0. Configure LLM access
# Before you open the coffee shop, make sure you configured the access to an LLM as described in the installation steps in the readme file.

# %% [markdown]
# ## 1. (Optional) How-to use this Jupyter notebook
#
# If you are used to Jupyter, feel free to skip this short introduction.
#
# To follow along with this hands-on session, we’ll be using the Jupyter web interface—a powerful, browser-based environment for interactive computing. Once you open the provided Jupyter notebook, you’ll see a series of cells that contain both code and explanatory text. Simply click on a cell to select it, then press Shift + Enter (or the play button on top) to execute the code and see the output directly below. Please note: All our provided scripts will at least print a success message for you (Right-click "Clear Cell Output"). Follow the instructions in each cell step by step, and (later!) feel free to modify the code to experiment and deepen your understanding. This setup allows you to learn by doing—right in your browser, with no additional setup required.
#
# All participants are isolated from each other meaning your changes will only influence your Agentic Coffee Shop. So, don't be shy and try it out.
#
# **Be aware:** Especially in this exercises, it can be necessary to restart the entire Jupyter kernel (runtime) to reflect your changes. You can do this by pushing the respective "Stop" or "Restart" button at the top. After that, you have to execute all code snippets from top to bottom again.

# %% [markdown]
# ## 2. Initialize the Coffee Shop
#
# Let's start with importing the necessary modules and set up our coffee shop. You just need to simply evaluate the code below. If you receive "Coffee shop has been initialized successfully!", everything is fine and you can go to the next step. Please be aware, initialization can require a couple of seconds (up to 1 min).

# %%
from src import CoffeeShop
from IPython.display import display

# Create the coffee shop instance
shop = CoffeeShop()

print("✅ Coffee shop has been initialized successfully!")

# %% [markdown]
# ## 3. Example extension: Pirate-speaking order agent
#
# As a warm up, it's your task to ensure that the order agent speaks like a pirate (or whatever you prefer). The following code is the original agent prompt that needs to be adapted by you. You can customize how the agents behave by simply adding your custom definitions as part of the prompt.
#
# Please ensure to execute this code in order to overwrite the original behavior and reopen the Coffee Shop (next script).

# %%
# Optional: Customize the order agent to speak like a pirate
order_agent_prompt = """You are a friendly order-taking agent at a coffee shop.

Your responsibilities:
- First, take customer orders and process them clearly
- Then, calculate totals and apply any discounts
- If you have completed the first two steps, transfer to inventory agent to check availability
- Handle order modifications from customer service

Be welcoming and helpful. Ask clarifying questions if orders are unclear.
As soon as you have the full order and calculated the total, confirm with the customer.
"""

shop.set_agent_definition("order_agent", order_agent_prompt)

print("✅ Agent customization complete!")

# %% [markdown]
# ## 4. Open the Coffee Shop
#
# We separated this step from the initialization to change the agents without restarting the entire system. Just execute this code as before and all the agents will be ready to serve!
#
# **Please note:** Sometimes this is not enough and a Jupyter Kernel restart is required (see also 1.)

# %%
# Open the shop (initialize all agents and the swarm)
shop.open_shop()

print("☕ Coffee Shop is now open and ready to serve!")

# %% [markdown]
# ## 5. Try it out
#
# Start the interactive coffee shop chat interface with the following code snippet.
#
# You can use this interface to:
#
# - **Use preset scenarios** by clicking the respective scenario buttons
# - **Type custom messages** in the text input box and click "Send" or pressing Enter to send the message
# - **Start new conversations** anytime with the "New Chat" button
# - **Verbose mode (Default: on)** can be switched off/on to better understand what happens in the background or to just focus on a great customer experience
# - **Restock all items** allows you to magically fill up the inventory again
#
# **Try it on your own by sending a respective message in the chat.**

# %%
# Create and display the interactive interface
interface = shop.create_interactive_interface()
display(interface)

# %% [markdown]
# ## 6. Further extension ideas
#
# Now, it's time for your creativity. **Either you can further extend the AI Coffee Shop or create new widgets within SAP Signavio Process Intelligence to get even more agentic insights**.
#
# Here are some ideas for extending the Coffee Shop:
# * *(Easy prompt)* Adapt agent prompts to improve customer experience, e.g., very exclusive treatment
# * *(Easy prompt)* Add some smalltalk before you get your order
# * *(Medium code)* Increase or decrease the failure rate of the Barista Agent and analyze the new traces
# * *(Medium code)* Add a new product to the menu and inventory
# * *(Difficult tool/prompt)* Ensure that the Order Agent knows the menu and doesn't hallucinate
# * *(Difficult tool/prompt)* The Order Agent checks with the Inventory Agent before and prevents orders that cannot be served or advertises full inventory items
# * *(Hard code/tool/prompt)* Create your own agents, e.g., a new Payment Agent
#
# ### Code overview
#
# On the left, you can access all the code for this exercise and as all instances are separated from each other, feel free to change whatever you want. Here is a brief introduction into the code base:
#
# * src/agents - Here you'll find all four agent definitions (Order, inventory, barista, and customer service agent) incl. their used tools
# * src/agents/shared_components.py - include shared state and constants for the menu, inventory, and agents handover tools
# * coffee_shop.py - finally, shouldn't be changed (only if you create a new agent) but provides a good overview how everything is glued together

# %% [markdown]
# ## 7. Mine agent behavior and transfer it to SAP Signavio Process Intelligence
#
# After you have created a couple of orders, it's now time to analyze the agent behavior and understand what has happened in the background. Therefore, you only have to execute the following code snippet that reads the logs generated from your interactions with the coffee shop and creates a basic event log. This event log contains all your past interactions with the shop and can be utilized for Process Mining using SAP Signavio Process Intelligence.
# One conversation can consist of multiple traces, as each trace comprises one input message provided by you and the subsequent actions taken by the agents. In other words, each message you send to the coffee shop creates a new trace.
#
# For instructions on how to upload the event log to Process Intelligence, refer to Section 4 of the [first exercise](1_Standard_agentic_coffee_shop.ipynb).

# %%
from src import TraceProcessor

processor = TraceProcessor()
processor.process_all_traces(export_as_json=False) # Set `export_as_json` to True to export as JSON instead of CSV
